# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go

# %% [markdown]
# # Import data

# %%
Vacancy_L1 = pd.read_csv('job-vacancy-rate-by-industry-level1.csv')
Vacancy_L2 = pd.read_csv('job-vacancy-rate-by-industry-level2.csv')
Vacancy_L3 = pd.read_csv('job-vacancy-rate-by-industry-level3.csv')
Recruitment_Resignation_L1 = pd.read_csv('average-monthly-recruitment-resignation-rate-by-industry-level1.csv')
Recruitment_Resignation_L2 = pd.read_csv('average-monthly-recruitment-resignation-rate-by-industry-level-2.csv')
Recruitment_Resignation_L3 = pd.read_csv('average-monthly-recruitment-resignation-rate-by-industry-level-3.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Drop data before 2013 and 2020 Quarter 1

# %%
def filter_data(df):
    df.drop(df[df['quarter'] < '2013'].index, inplace=True)
    df.drop(df[df['quarter'] > '2020'].index, inplace=True)

# %%
filter_data(Recruitment_Resignation_L1)
filter_data(Vacancy_L1)
filter_data(Recruitment_Resignation_L2)
filter_data(Vacancy_L2)
filter_data(Recruitment_Resignation_L3)
filter_data(Vacancy_L3)

# %% [markdown]
# ## 2. Merge data

# %%
all_L1_df = Recruitment_Resignation_L1.merge(Vacancy_L1)
all_L2_df = Recruitment_Resignation_L2.merge(Vacancy_L2)
all_L3_df = Recruitment_Resignation_L3.merge(Vacancy_L3)

# %%
all_L1_df.groupby('industry1').mean()
# Out:
#                recruitment_rate  resignation_rate  job_vacancy_rate
# industry1
# construction           2.346429          1.810714          0.939286
# manufacturing          1.742857          1.500000          1.907143
# others                 1.714286          1.375000          2.178571
# services               2.550000          1.989286          3.192857

# %% [markdown]
# ## 3. Removing the quarters from the years

# %% [markdown]
# # Plot Data

# %% [markdown]
# ## 1. EDA from 2013 to 2019

# %%
all_L1_df.head()
# Out:
#    quarter      industry1  recruitment_rate  resignation_rate  \
# 0  2013-Q1  manufacturing               1.6               1.6
# 1  2013-Q1   construction               3.6               2.1
# 2  2013-Q1       services               2.8               2.3
# 3  2013-Q1         others               2.2               1.8
# 4  2013-Q2  manufacturing               2.2               1.6
#
#    job_vacancy_rate
# 0               1.9
# 1               1.4
# 2               3.1
# 3               4.2
# 4               1.9

# %%
# Create the figure
fig_dimensions=(20, 15)
fig = plt.figure(figsize = fig_dimensions)

# Add First subplot
ax1 = fig.add_subplot(2,1,1)
sns.set(style="darkgrid")
ax1 = sns.lineplot(data = all_L1_df, x='quarter', y='recruitment_rate', hue='industry1', style='industry1', size = 'industry1', palette="muted", markers=True, dashes=True)
ax1.set_title("Recruitment Rate for the categories of Industries, 2013-2019", fontsize=20)
ax1.set_ylabel("Recruitment Rate",fontsize=12)
ax1.set_xlabel("Year",fontsize=12)
plt.xticks(rotation=90)

# Add second subplot
ax1 = fig.add_subplot(2,1,2)
sns.set(style="darkgrid")
ax1 = sns.lineplot(data = all_L1_df, x='quarter', y='job_vacancy_rate', hue='industry1', style='industry1', size = 'industry1', palette="muted", markers=True, dashes=True)
ax1.set_title("Vacancy Rate for the categories of Industries, 2013-2019", fontsize=20)
ax1.set_ylabel("Vacancy Rate",fontsize=12)
ax1.set_xlabel("Year",fontsize=12)
plt.xticks(rotation=90)

plt.subplots_adjust(hspace = 0.3)
plt.show()

# %% [markdown]
# As seen from the above graphs, "services" industry has the highest recruitment rate and job vacancy rate. These suggests there is a high demand for labour in this sector. Hence, our group will be focusing on the "services" industry by looking at the breakdown of the categories under the it.

# %%
services = all_L2_df['industry1'] == 'services'
all_L2_services_df = all_L2_df[services]
all_L2_services_df['industry2'].unique()
# Out:
# array(['wholesale and retail trade', 'transportation and storage',
#        'accommodation and food services',
#        'information and communications',
#        'financial and insurance services', 'real estate services',
#        'professional services', 'administrative and support services',
#        'community, social and personal services'], dtype=object)

# %%
# Create the figure
fig_dimensions=(25, 30)
fig = plt.figure(figsize = fig_dimensions)

# Add First subplot
ax1 = fig.add_subplot(2,1,1)
sns.set(style="darkgrid")
ax1 = sns.lineplot(data = all_L2_services_df, x='quarter', y='recruitment_rate', hue='industry2', size='industry2', palette="Set1", markers=True, dashes=True)
ax1.set_title("Recruitment Rate for the service sector, 2013-2019", fontsize=24)
ax1.set_ylabel("Recruitment Rate",fontsize=14)
ax1.set_xlabel("Year",fontsize=14)
plt.xticks(rotation=90)

# Add second subplot
ax1 = fig.add_subplot(2,1,2)
sns.set(style="darkgrid")
ax1 = sns.lineplot(data = all_L2_services_df, x='quarter', y='job_vacancy_rate', hue='industry2', size = 'industry2', palette="Set1", markers=True, dashes=True)
ax1.set_title("Vacancy Rate for the service sector, 2013-2019", fontsize=24)
ax1.set_ylabel("Vacancy Rate",fontsize=14)
ax1.set_xlabel("Year",fontsize=14)
plt.xticks(rotation=90)

plt.subplots_adjust(hspace = 0.2)
plt.show()

# %% [markdown]
# From the graph above, there is no insightful result we can get from recruitment rate. Whereas from the job vacancy graph, the general trend for most of the industry rate is decreasing but this is not the case for "information and communication". Therefore, we will further look into the "information and communication" sector.

# %%
it_services = all_L3_df['industry2'] == 'information and communications'
all_L3_services_df = all_L3_df[it_services]
all_L3_services_df['industry3'].unique()
# Out:
# array(['telecommunications, broadcasting and publishing',
#        'it and other information services'], dtype=object)

# %%
# Create the figure
fig_dimensions=(25, 20)
fig = plt.figure(figsize = fig_dimensions)

# Add First subplot
ax1 = fig.add_subplot(2,1,1)
sns.set(style="darkgrid")
ax1 = sns.lineplot(data = all_L3_services_df, x='quarter', y='recruitment_rate', style = 'industry3', hue='industry3', palette="Set1", markers=True, dashes=True)
ax1.set_title("Recruitment Rate for the IT sector, 2013-2019", fontsize=20)
ax1.set_ylabel("Recruitment Rate",fontsize=14)
ax1.set_xlabel("Year",fontsize=14)
plt.xticks(rotation=90)

# Add second subplot
ax1 = fig.add_subplot(2,1,2)
sns.set(style="darkgrid")
ax1 = sns.lineplot(data = all_L3_services_df, x='quarter', y='job_vacancy_rate',style = 'industry3', hue='industry3', palette="Set1", markers=True, dashes=True)
ax1.set_title("Vacancy Rate for the IT sector, 2013-2019", fontsize=20)
ax1.set_ylabel("Vacancy Rate",fontsize=14)
ax1.set_xlabel("Year",fontsize=14)
plt.xticks(rotation=90)

plt.subplots_adjust(hspace = 0.3)
plt.show()

# %% [markdown]
# From result above, we came to a conclusion that "IT and other services" is rising in manpower demand.

# %%
cond = all_L3_services_df['industry3'] == 'it and other information services'
infocomm_df = all_L3_services_df[cond]
infocomm_df.head()
# Out:
#      quarter industry1                       industry2  \
# 17   2013-Q1  services  information and communications
# 49   2013-Q2  services  information and communications
# 81   2013-Q3  services  information and communications
# 113  2013-Q4  services  information and communications
# 145  2014-Q1  services  information and communications
#
#                              industry3  recruitment_rate  resignation_rate  \
# 17   it and other information services               2.8               2.1
# 49   it and other information services               3.2               2.5
# 81   it and other information services               3.4               2.4
# 113  it and other information services               2.8               1.9
# 145  it and other information services               3.1               2.0
#
#      job_vacancy_rate
# 17                2.6
# 49                2.5
# 81                3.4
# 113               3.7
# 145               4.2

# %%
def transformquarter(row):
    return row[:4]

# %%
all_L1_df['quarter'] = all_L1_df['quarter'].apply(transformquarter)
all_L2_df['quarter'] = all_L2_df['quarter'].apply(transformquarter)
all_L3_df['quarter'] = all_L3_df['quarter'].apply(transformquarter)

# %%
# Create the figure
fig_dimensions=(25, 20)
fig = plt.figure(figsize = fig_dimensions)

# Plot Graph
sns.set(style="darkgrid")
ax1 = sns.lmplot(x="quarter", y="recruitment_rate",data = infocomm_df)
# ax1.set_title("Recruitment Rate for the IT sector, 2013-2019", fontsize=20)
# ax1.set_ylabel("Recruitment Rate",fontsize=14)
# ax1.set_xlabel("Year",fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-33-546d760e5a93> in <module>
#       5 # Plot Graph
#       6 sns.set(style="darkgrid")
# ----> 7 ax1 = sns.regplot(x="quarter", y="recruitment_rate",data = infocomm_df)
#       8 # ax1.set_title("Recruitment Rate for the IT sector, 2013-2019", fontsize=20)
#       9 # ax1.set_ylabel("Recruitment Rate",fontsize=14)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     815     scatter_kws["marker"] = marker
#     816     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 817     plotter.plot(ax, scatter_kws, line_kws)
#     818     return ax
#     819
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     367
#     368         if self.fit_reg:
# --> 369             self.lineplot(ax, line_kws)
#     370
#     371         # Label the axes
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/regression.py in lineplot(self, ax, kws)
#     410         """Draw the model."""
#     411         # Fit the regression model
# --> 412         grid, yhat, err_bands = self.fit_regression(ax)
#     413         edges = grid[0], grid[-1]
#     414
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/regression.py in fit_regression(self, ax, x_range, grid)
#     198                 else:
#     199                     x_min, x_max = ax.get_xlim()
# --> 200             grid = np.linspace(x_min, x_max, 100)
#     201         ci = self.ci
#     202
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     127     # Convert float/complex array scalars to float, gh-3504
#     128     # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 129     start = asanyarray(start) * 1.0
#     130     stop  = asanyarray(stop)  * 1.0
#     131
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')
